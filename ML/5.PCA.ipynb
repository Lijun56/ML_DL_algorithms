# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## simple PCA

# %%
X = np.empty((100, 2))
X[:, 0] = np.random.uniform(0, 100, size = 100)
X[:, 1] = 0.75 * X[:, 0] + 3 + np.random.normal(0, 10, size =100)

plt.scatter(X[:,0], X[:, 1])
plt.show()

# %% [markdown]
# PCA is to find a line that allow all points represented in the line can have largest variance
#
# so we want to remove mean value of all (for easier calculate vairance)
# second, we want to find the direction using
